# %%
# %matplotlib QT5
import numpy as np
import matplotlib.pyplot as plt

import pyaccel
import pymodels
from apsuite import lattice_errors
from apsuite.orbcorr import OrbitCorr, CorrParams
from mathphys.functions import save_pickle, load_pickle

# %% [markdown]
# Creating errors configs

# %%
dips_error = lattice_errors.DipolesErrors()
quads_error = lattice_errors.QuadsErrors()
quads_skew_error = lattice_errors.QuadsSkewErrors()
sexts_error = lattice_errors.SextsErrors()
girder_error = lattice_errors.GirderErrors()
bpms_error = lattice_errors.BpmsErrors()
error_configs = [dips_error, quads_error, sexts_error, quads_skew_error,
                 bpms_error, girder_error]
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.

# %% [markdown]
# Generate errors and save in a file

# %%
# get family data
model = pymodels.si.create_accelerator()
model.cavity_on = False
model.radiation_on = 0
famdata = pymodels.si.families.get_family_data(model)
# create a seed
seed = 148670

# create manage errors object
lattice_errors = lattice_errors.ManageErrors()
lattice_errors.nr_mach = 20
lattice_errors.nominal_model = model
lattice_errors.famdata = famdata
lattice_errors.seed = seed
lattice_errors.error_configs = error_configs
lattice_errors.cutoff = 1

# %%
errors = lattice_errors.generate_errors(save_errors=True)

# %% [markdown]
# Load error file

# %%
data = lattice_errors.load_error_file(
    str(lattice_errors.nr_mach)+'_errors_seed_'+str(seed))
print(lattice_errors.nr_mach)
print(data.keys())
print('B1:')
print(data['B1'].keys())
print(np.shape(data['B1']['index']))
print(np.shape(data['B1']['posx']))
print('QFA:')
print(data['QFA'].keys())
print(np.shape(data['QFA']['index']))
print(np.shape(data['QFA']['posx']))
print(data['QFA']['multipoles'].keys())
# Out:
# 20
# dict_keys(['B1', 'B2', 'BC', 'QFA', 'QDA', 'Q1', 'Q2', 'Q3', 'Q4', 'QDB1', 'QFB', 'QDB2', 'QDP1', 'QFP', 'QDP2', 'SFA0', 'SDA0', 'SDA1', 'SFA1', 'SDA2', 'SDA3', 'SFA2', 'SFB2', 'SDB3', 'SDB2', 'SFB1', 'SDB1', 'SDB0', 'SFB0', 'SFP2', 'SDP3', 'SDP2', 'SFP1', 'SDP1', 'SDP0', 'SFP0', 'QS', 'BPM', 'girder'])
# B1:
# dict_keys(['posx', 'posy', 'roll', 'pitch', 'yaw', 'excit', 'kdip', 'multipoles', 'index'])
# (40, 30)
# (20, 40)
# QFA:
# dict_keys(['posx', 'posy', 'roll', 'pitch', 'yaw', 'excit', 'multipoles', 'index'])
# (10, 1)
# (20, 10)
# dict_keys(['normal', 'skew', 'r0'])

# %%
lattice_errors.load_jacobians = True
lattice_errors.configure_corrections()
# Out:
# Configuring orbit correction...
# Configuring optics correction...
# Configuring tune correction...
# Nominal tunes: 49.0960 14.1518
# Configuring coupling correction...

# %%
lattice_errors.nr_mach = 20

# correction with girder errors: 8 steps

lattice_errors.ramp_tunes = True
lattice_errors.ramp_coup = True
lattice_errors.ramp_optics = True
lattice_errors.apply_girder = True
lattice_errors.rescale_girder = 1

lattice_errors.do_bba = True
lattice_errors.ocorr_params.minsingval = 0.1
lattice_errors.ocorr_params.maxnriters = 20
lattice_errors.ocorr_params.tolerance = 1e-9
data_mach = lattice_errors.generate_machines(nr_steps=8)
# Out:
# Machine  0
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.126 %
# Minimum tune separation after corr: 0.021 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.123 %
# Minimum tune separation after corr: 0.043 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1514
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.114 %
# Minimum tune separation after corr: 0.066 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1513
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.094 %
# Minimum tune separation after corr: 0.090 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0948 14.1512
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.055 %
# Minimum tune separation after corr: 0.114 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0945 14.1511
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.070 %
# Minimum tune separation after corr: 0.139 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0941 14.1510
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.121 %
# Minimum tune separation after corr: 0.164 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0936 14.1510
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.162 %
# Minimum tune separation after corr: 0.189 %
# Machine  1
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.013 %
# Minimum tune separation after corr: 0.031 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.088 %
# Minimum tune separation after corr: 0.061 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.132 %
# Minimum tune separation after corr: 0.090 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.170 %
# Minimum tune separation after corr: 0.119 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.206 %
# Minimum tune separation after corr: 0.148 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.240 %
# Minimum tune separation after corr: 0.176 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1524
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.273 %
# Minimum tune separation after corr: 0.204 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1526
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.305 %
# Minimum tune separation after corr: 0.232 %
# Machine  2
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.376 %
# Minimum tune separation after corr: 0.017 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.362 %
# Minimum tune separation after corr: 0.034 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.347 %
# Minimum tune separation after corr: 0.053 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.332 %
# Minimum tune separation after corr: 0.071 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0953 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.315 %
# Minimum tune separation after corr: 0.090 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0950 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.298 %
# Minimum tune separation after corr: 0.109 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0947 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.279 %
# Minimum tune separation after corr: 0.128 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0944 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.259 %
# Minimum tune separation after corr: 0.148 %
# Machine  3
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.181 %
# Minimum tune separation after corr: 0.013 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.160 %
# Minimum tune separation after corr: 0.023 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.137 %
# Minimum tune separation after corr: 0.031 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.107 %
# Minimum tune separation after corr: 0.037 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.066 %
# Minimum tune separation after corr: 0.038 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.050 %
# Minimum tune separation after corr: 0.034 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1525
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.095 %
# Minimum tune separation after corr: 0.017 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1526
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.122 %
# Minimum tune separation after corr: 0.038 %
# Machine  4
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.138 %
# Minimum tune separation after corr: 0.023 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.159 %
# Minimum tune separation after corr: 0.045 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.175 %
# Minimum tune separation after corr: 0.067 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.188 %
# Minimum tune separation after corr: 0.088 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.199 %
# Minimum tune separation after corr: 0.109 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0949 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.208 %
# Minimum tune separation after corr: 0.128 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0945 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.216 %
# Minimum tune separation after corr: 0.146 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0941 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.223 %
# Minimum tune separation after corr: 0.163 %
# Machine  5
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.381 %
# Minimum tune separation after corr: 0.010 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.370 %
# Minimum tune separation after corr: 0.020 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.359 %
# Minimum tune separation after corr: 0.030 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.348 %
# Minimum tune separation after corr: 0.040 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.337 %
# Minimum tune separation after corr: 0.049 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.326 %
# Minimum tune separation after corr: 0.058 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.315 %
# Minimum tune separation after corr: 0.065 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1525
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.198 %
# Minimum tune separation after corr: 0.070 %
# Machine  6
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.100 %
# Minimum tune separation after corr: 0.006 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.094 %
# Minimum tune separation after corr: 0.013 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.088 %
# Minimum tune separation after corr: 0.021 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.082 %
# Minimum tune separation after corr: 0.028 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.076 %
# Minimum tune separation after corr: 0.036 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0962 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.071 %
# Minimum tune separation after corr: 0.045 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0962 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.066 %
# Minimum tune separation after corr: 0.053 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0962 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.035 %
# Minimum tune separation after corr: 0.060 %
# Machine  7
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.066 %
# Minimum tune separation after corr: 0.010 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.068 %
# Minimum tune separation after corr: 0.024 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.064 %
# Minimum tune separation after corr: 0.041 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.049 %
# Minimum tune separation after corr: 0.060 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.023 %
# Minimum tune separation after corr: 0.082 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.070 %
# Minimum tune separation after corr: 0.104 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.104 %
# Minimum tune separation after corr: 0.128 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1524
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.135 %
# Minimum tune separation after corr: 0.152 %
# Machine  8
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.150 %
# Minimum tune separation after corr: 0.012 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.140 %
# Minimum tune separation after corr: 0.028 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.131 %
# Minimum tune separation after corr: 0.047 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.124 %
# Minimum tune separation after corr: 0.068 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0949 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.119 %
# Minimum tune separation after corr: 0.089 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0946 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.115 %
# Minimum tune separation after corr: 0.111 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0942 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.114 %
# Minimum tune separation after corr: 0.132 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0937 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.116 %
# Minimum tune separation after corr: 0.151 %
# Machine  9
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.199 %
# Minimum tune separation after corr: 0.017 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.221 %
# Minimum tune separation after corr: 0.035 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.239 %
# Minimum tune separation after corr: 0.054 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.254 %
# Minimum tune separation after corr: 0.073 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.267 %
# Minimum tune separation after corr: 0.093 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.277 %
# Minimum tune separation after corr: 0.114 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0953 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.285 %
# Minimum tune separation after corr: 0.136 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.291 %
# Minimum tune separation after corr: 0.158 %
# Machine  10
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.021 %
# Minimum tune separation after corr: 0.007 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.049 %
# Minimum tune separation after corr: 0.009 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.069 %
# Minimum tune separation after corr: 0.010 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.089 %
# Minimum tune separation after corr: 0.026 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.110 %
# Minimum tune separation after corr: 0.043 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.132 %
# Minimum tune separation after corr: 0.063 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.155 %
# Minimum tune separation after corr: 0.084 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.181 %
# Minimum tune separation after corr: 0.108 %
# Machine  11
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.243 %
# Minimum tune separation after corr: 0.028 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.239 %
# Minimum tune separation after corr: 0.056 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.230 %
# Minimum tune separation after corr: 0.085 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.217 %
# Minimum tune separation after corr: 0.114 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.197 %
# Minimum tune separation after corr: 0.144 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.168 %
# Minimum tune separation after corr: 0.174 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.124 %
# Minimum tune separation after corr: 0.204 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1525
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.012 %
# Minimum tune separation after corr: 0.235 %
# Machine  12
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.446 %
# Minimum tune separation after corr: 0.036 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.431 %
# Minimum tune separation after corr: 0.080 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1525
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.413 %
# Minimum tune separation after corr: 0.131 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1529
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.391 %
# Minimum tune separation after corr: 0.187 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0948 14.1535
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.360 %
# Minimum tune separation after corr: 0.248 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0943 14.1542
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.319 %
# Minimum tune separation after corr: 0.313 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0937 14.1550
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.257 %
# Minimum tune separation after corr: 0.381 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0930 14.1559
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.153 %
# Minimum tune separation after corr: 0.453 %
# Machine  13
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.208 %
# Minimum tune separation after corr: 0.007 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.203 %
# Minimum tune separation after corr: 0.014 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.198 %
# Minimum tune separation after corr: 0.018 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.192 %
# Minimum tune separation after corr: 0.022 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0962 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.187 %
# Minimum tune separation after corr: 0.023 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0963 14.1524
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.181 %
# Minimum tune separation after corr: 0.021 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0964 14.1526
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.175 %
# Minimum tune separation after corr: 0.015 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0964 14.1528
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.137 %
# Minimum tune separation after corr: 0.018 %
# Machine  14
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.026 %
# Minimum tune separation after corr: 0.011 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.040 %
# Minimum tune separation after corr: 0.021 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.064 %
# Minimum tune separation after corr: 0.032 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1514
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.083 %
# Minimum tune separation after corr: 0.043 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1514
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.100 %
# Minimum tune separation after corr: 0.055 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0953 14.1513
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.115 %
# Minimum tune separation after corr: 0.067 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1513
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.129 %
# Minimum tune separation after corr: 0.079 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1513
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.143 %
# Minimum tune separation after corr: 0.091 %
# Machine  15
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.142 %
# Minimum tune separation after corr: 0.008 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.146 %
# Minimum tune separation after corr: 0.014 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.151 %
# Minimum tune separation after corr: 0.019 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0953 14.1514
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.158 %
# Minimum tune separation after corr: 0.023 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1513
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.166 %
# Minimum tune separation after corr: 0.023 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0948 14.1512
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.175 %
# Minimum tune separation after corr: 0.019 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0945 14.1511
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.186 %
# Minimum tune separation after corr: 0.011 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0941 14.1510
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.198 %
# Minimum tune separation after corr: 0.032 %
# Machine  16
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.313 %
# Minimum tune separation after corr: 0.010 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.306 %
# Minimum tune separation after corr: 0.016 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.300 %
# Minimum tune separation after corr: 0.016 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.294 %
# Minimum tune separation after corr: 0.012 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.289 %
# Minimum tune separation after corr: 0.035 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.285 %
# Minimum tune separation after corr: 0.057 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0953 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.284 %
# Minimum tune separation after corr: 0.080 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.285 %
# Minimum tune separation after corr: 0.106 %
# Machine  17
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.080 %
# Minimum tune separation after corr: 0.012 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.103 %
# Minimum tune separation after corr: 0.026 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.119 %
# Minimum tune separation after corr: 0.040 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1514
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.132 %
# Minimum tune separation after corr: 0.055 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1513
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.141 %
# Minimum tune separation after corr: 0.072 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1513
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.148 %
# Minimum tune separation after corr: 0.089 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1512
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.151 %
# Minimum tune separation after corr: 0.106 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0949 14.1511
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.152 %
# Minimum tune separation after corr: 0.125 %
# Machine  18
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.111 %
# Minimum tune separation after corr: 0.017 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.103 %
# Minimum tune separation after corr: 0.033 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.089 %
# Minimum tune separation after corr: 0.049 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.068 %
# Minimum tune separation after corr: 0.063 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.028 %
# Minimum tune separation after corr: 0.077 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.060 %
# Minimum tune separation after corr: 0.090 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.091 %
# Minimum tune separation after corr: 0.102 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0962 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.116 %
# Minimum tune separation after corr: 0.112 %
# Machine  19
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.333 %
# Minimum tune separation after corr: 0.022 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.322 %
# Minimum tune separation after corr: 0.044 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.312 %
# Minimum tune separation after corr: 0.066 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.303 %
# Minimum tune separation after corr: 0.087 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0953 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.296 %
# Minimum tune separation after corr: 0.107 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.291 %
# Minimum tune separation after corr: 0.127 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0950 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.288 %
# Minimum tune separation after corr: 0.145 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0947 14.1525
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.288 %
# Minimum tune separation after corr: 0.162 %

# %%
lattice_errors.reset_seed()
lattice_errors.generate_errors(save_errors=True)
data_mach = lattice_errors.generate_machines(nr_steps=8)
# Out:
# New seed:  414208
# Machine  0
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.145 %
# Minimum tune separation after corr: 0.033 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.147 %
# Minimum tune separation after corr: 0.066 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.141 %
# Minimum tune separation after corr: 0.100 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.128 %
# Minimum tune separation after corr: 0.133 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.104 %
# Minimum tune separation after corr: 0.166 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1525
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.056 %
# Minimum tune separation after corr: 0.199 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1528
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.079 %
# Minimum tune separation after corr: 0.231 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1531
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.132 %
# Minimum tune separation after corr: 0.263 %
# Machine  1
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.167 %
# Minimum tune separation after corr: 0.014 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.162 %
# Minimum tune separation after corr: 0.027 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.155 %
# Minimum tune separation after corr: 0.041 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.147 %
# Minimum tune separation after corr: 0.055 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0962 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.137 %
# Minimum tune separation after corr: 0.068 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0962 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.125 %
# Minimum tune separation after corr: 0.082 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0963 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.110 %
# Minimum tune separation after corr: 0.096 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0963 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.090 %
# Minimum tune separation after corr: 0.109 %
# Machine  2
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.132 %
# Minimum tune separation after corr: 0.019 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.137 %
# Minimum tune separation after corr: 0.038 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.138 %
# Minimum tune separation after corr: 0.059 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.133 %
# Minimum tune separation after corr: 0.080 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.123 %
# Minimum tune separation after corr: 0.102 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1525
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.106 %
# Minimum tune separation after corr: 0.124 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1528
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.075 %
# Minimum tune separation after corr: 0.147 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1531
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.040 %
# Minimum tune separation after corr: 0.170 %
# Machine  3
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.329 %
# Minimum tune separation after corr: 0.024 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.348 %
# Minimum tune separation after corr: 0.047 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.365 %
# Minimum tune separation after corr: 0.069 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.382 %
# Minimum tune separation after corr: 0.091 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.397 %
# Minimum tune separation after corr: 0.110 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.413 %
# Minimum tune separation after corr: 0.129 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0949 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.428 %
# Minimum tune separation after corr: 0.146 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0946 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.443 %
# Minimum tune separation after corr: 0.162 %
# Machine  4
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.242 %
# Minimum tune separation after corr: 0.014 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.261 %
# Minimum tune separation after corr: 0.034 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.276 %
# Minimum tune separation after corr: 0.059 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1524
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.287 %
# Minimum tune separation after corr: 0.088 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1527
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.292 %
# Minimum tune separation after corr: 0.121 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0948 14.1531
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.292 %
# Minimum tune separation after corr: 0.157 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0944 14.1536
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.285 %
# Minimum tune separation after corr: 0.195 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0939 14.1542
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.271 %
# Minimum tune separation after corr: 0.237 %
# Machine  5
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.094 %
# Minimum tune separation after corr: 0.020 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.096 %
# Minimum tune separation after corr: 0.038 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0962 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.093 %
# Minimum tune separation after corr: 0.055 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0963 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.086 %
# Minimum tune separation after corr: 0.071 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0963 14.1524
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.075 %
# Minimum tune separation after corr: 0.085 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0964 14.1525
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.060 %
# Minimum tune separation after corr: 0.097 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0965 14.1526
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.036 %
# Minimum tune separation after corr: 0.106 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0965 14.1528
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.096 %
# Minimum tune separation after corr: 0.112 %
# Machine  6
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.228 %
# Minimum tune separation after corr: 0.003 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.222 %
# Minimum tune separation after corr: 0.009 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.215 %
# Minimum tune separation after corr: 0.018 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.207 %
# Minimum tune separation after corr: 0.029 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.200 %
# Minimum tune separation after corr: 0.042 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.193 %
# Minimum tune separation after corr: 0.056 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.186 %
# Minimum tune separation after corr: 0.072 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.180 %
# Minimum tune separation after corr: 0.089 %
# Machine  7
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.209 %
# Minimum tune separation after corr: 0.006 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.211 %
# Minimum tune separation after corr: 0.012 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.215 %
# Minimum tune separation after corr: 0.019 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.220 %
# Minimum tune separation after corr: 0.026 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.227 %
# Minimum tune separation after corr: 0.033 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0953 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.234 %
# Minimum tune separation after corr: 0.040 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.242 %
# Minimum tune separation after corr: 0.046 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0949 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.251 %
# Minimum tune separation after corr: 0.052 %
# Machine  8
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.266 %
# Minimum tune separation after corr: 0.012 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.264 %
# Minimum tune separation after corr: 0.025 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.263 %
# Minimum tune separation after corr: 0.037 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.261 %
# Minimum tune separation after corr: 0.050 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.259 %
# Minimum tune separation after corr: 0.063 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.257 %
# Minimum tune separation after corr: 0.075 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.254 %
# Minimum tune separation after corr: 0.088 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.251 %
# Minimum tune separation after corr: 0.101 %
# Machine  9
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.220 %
# Minimum tune separation after corr: 0.009 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.209 %
# Minimum tune separation after corr: 0.018 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.197 %
# Minimum tune separation after corr: 0.029 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.185 %
# Minimum tune separation after corr: 0.040 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.173 %
# Minimum tune separation after corr: 0.052 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.161 %
# Minimum tune separation after corr: 0.064 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.149 %
# Minimum tune separation after corr: 0.078 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.138 %
# Minimum tune separation after corr: 0.092 %
# Machine  10
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.155 %
# Minimum tune separation after corr: 0.027 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.107 %
# Minimum tune separation after corr: 0.048 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.046 %
# Minimum tune separation after corr: 0.062 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.126 %
# Minimum tune separation after corr: 0.065 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1524
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.169 %
# Minimum tune separation after corr: 0.048 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1527
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.198 %
# Minimum tune separation after corr: 0.055 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0953 14.1531
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.215 %
# Minimum tune separation after corr: 0.116 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1535
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.220 %
# Minimum tune separation after corr: 0.174 %
# Machine  11
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.307 %
# Minimum tune separation after corr: 0.005 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.308 %
# Minimum tune separation after corr: 0.010 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.308 %
# Minimum tune separation after corr: 0.014 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.309 %
# Minimum tune separation after corr: 0.019 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.309 %
# Minimum tune separation after corr: 0.023 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.309 %
# Minimum tune separation after corr: 0.027 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.309 %
# Minimum tune separation after corr: 0.031 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.309 %
# Minimum tune separation after corr: 0.034 %
# Machine  12
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.234 %
# Minimum tune separation after corr: 0.007 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.253 %
# Minimum tune separation after corr: 0.014 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.270 %
# Minimum tune separation after corr: 0.022 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1524
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.286 %
# Minimum tune separation after corr: 0.030 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1526
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.302 %
# Minimum tune separation after corr: 0.039 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1529
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.317 %
# Minimum tune separation after corr: 0.049 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0953 14.1532
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.331 %
# Minimum tune separation after corr: 0.058 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0951 14.1536
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.345 %
# Minimum tune separation after corr: 0.069 %
# Machine  13
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.065 %
# Minimum tune separation after corr: 0.021 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.067 %
# Minimum tune separation after corr: 0.043 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.063 %
# Minimum tune separation after corr: 0.064 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.051 %
# Minimum tune separation after corr: 0.086 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.023 %
# Minimum tune separation after corr: 0.107 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1522
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.048 %
# Minimum tune separation after corr: 0.128 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.076 %
# Minimum tune separation after corr: 0.149 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0961 14.1524
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.100 %
# Minimum tune separation after corr: 0.169 %
# Machine  14
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.466 %
# Minimum tune separation after corr: 0.018 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.459 %
# Minimum tune separation after corr: 0.040 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.447 %
# Minimum tune separation after corr: 0.065 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1523
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.427 %
# Minimum tune separation after corr: 0.093 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1525
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.400 %
# Minimum tune separation after corr: 0.121 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1528
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.362 %
# Minimum tune separation after corr: 0.151 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0950 14.1531
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.309 %
# Minimum tune separation after corr: 0.181 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0947 14.1534
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.232 %
# Minimum tune separation after corr: 0.211 %
# Machine  15
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.351 %
# Minimum tune separation after corr: 0.013 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.344 %
# Minimum tune separation after corr: 0.026 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.336 %
# Minimum tune separation after corr: 0.040 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.328 %
# Minimum tune separation after corr: 0.054 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.318 %
# Minimum tune separation after corr: 0.068 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.308 %
# Minimum tune separation after corr: 0.082 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.297 %
# Minimum tune separation after corr: 0.097 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.285 %
# Minimum tune separation after corr: 0.111 %
# Machine  16
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.041 %
# Minimum tune separation after corr: 0.007 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.070 %
# Minimum tune separation after corr: 0.013 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.091 %
# Minimum tune separation after corr: 0.018 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.108 %
# Minimum tune separation after corr: 0.023 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1518
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.123 %
# Minimum tune separation after corr: 0.026 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.136 %
# Minimum tune separation after corr: 0.028 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.148 %
# Minimum tune separation after corr: 0.028 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1520
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.158 %
# Minimum tune separation after corr: 0.026 %
# Machine  17
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.140 %
# Minimum tune separation after corr: 0.014 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.150 %
# Minimum tune separation after corr: 0.027 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.157 %
# Minimum tune separation after corr: 0.040 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1515
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.164 %
# Minimum tune separation after corr: 0.052 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0953 14.1514
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.168 %
# Minimum tune separation after corr: 0.063 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1514
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.172 %
# Minimum tune separation after corr: 0.072 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0950 14.1514
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.176 %
# Minimum tune separation after corr: 0.080 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0949 14.1514
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.178 %
# Minimum tune separation after corr: 0.087 %
# Machine  18
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1519
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.165 %
# Minimum tune separation after corr: 0.015 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0960 14.1521
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.159 %
# Minimum tune separation after corr: 0.017 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1525
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.168 %
# Minimum tune separation after corr: 0.060 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1530
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.196 %
# Minimum tune separation after corr: 0.112 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1537
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.242 %
# Minimum tune separation after corr: 0.176 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1546
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.306 %
# Minimum tune separation after corr: 0.250 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0954 14.1556
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.384 %
# Minimum tune separation after corr: 0.337 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0952 14.1566
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.426 %
# Minimum tune separation after corr: 0.412 %
# Machine  19
# Step  1
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.074 %
# Minimum tune separation after corr: 0.014 %
# Step  2
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0959 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.065 %
# Minimum tune separation after corr: 0.027 %
# Step  3
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1517
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.054 %
# Minimum tune separation after corr: 0.038 %
# Step  4
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0958 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.038 %
# Minimum tune separation after corr: 0.049 %
# Step  5
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.011 %
# Minimum tune separation after corr: 0.057 %
# Step  6
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0957 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.031 %
# Minimum tune separation after corr: 0.064 %
# Step  7
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0956 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.041 %
# Minimum tune separation after corr: 0.068 %
# Step  8
# Correcting orbit...Done!
#
# Optics correction tolerance achieved:  False
# Old tunes: 49.0955 14.1516
# iter # 1 - New tunes: 49.0960 14.1518
# Minimum tune separation before corr: 0.043 %
# Minimum tune separation after corr: 0.068 %

# %% [markdown]
# Load data

# %%
data_mach = load_pickle('20_machines_seed_414208.pickle')

# %% [markdown]
# plot final COD for all machines

# %%
plt.figure()
for mach in np.arange(0,20):
    orbf = data_mach[mach]['data']['step_7']['orbit']
    orb0 = data_mach[mach]['data']['step_7']['ref_orb']
    cod = orbf-orb0
    plt.plot(1e6*cod)

# %% [markdown]
# Plot final correctors kicks for all machines

# %%
plt.figure()
for mach in np.arange(0,20):
    kicks7 = data_mach[mach]['data']['step_7']['corr_kicks'][:-1]
    # kicks6 = data_mach[mach]['data']['step_6']['corr_kicks'][:-1]
    # deltakick = kicks7 - kicks6
    plt.plot(1e6*kicks7)

# %% [markdown]
# Verify if final COD is in the null-space of orb respmat

# %%
plt.figure()
minsingval = 0.1
respmats = load_pickle('respmats.pickle')
orbmat = respmats['orbmat']


umat, smat, vmat = np.linalg.svd(orbmat, full_matrices=False)
idx = smat > minsingval
ismat = np.zeros(smat.shape, dtype=float)
ismat[idx] = 1/smat[idx]
ismat = np.dot(vmat.T*ismat, umat.T)
for mach in np.arange(0,20):
    orbf = data_mach[mach]['data']['step_7']['orbit']
    orb0 = data_mach[mach]['data']['step_7']['ref_orb']
    cod = orbf-orb0
    dkicks = -1*np.dot(ismat, cod)
    plt.plot(1e6*dkicks)

# %% [markdown]
# Plot final beta-beating for all machines

# %%
fig, axs = plt.subplots(2)

for mach in range(20):
    bbeatx = data_mach[mach]['data']['step_7']['betabeatingx']
    bbeaty = data_mach[mach]['data']['step_7']['betabeatingy']
    print('{:.2f} %'.format(np.std(bbeatx)))
    print('{:.2f} %'.format(np.std(bbeaty)))
    print()
    axs[0].plot(bbeatx, label=mach)
    axs[1].plot(bbeatx, label=mach)
axs[0].legend()
# Out:
# 1.05 %
# 0.53 %
#
# 0.67 %
# 0.30 %
#
# 1.65 %
# 0.96 %
#
# 0.65 %
# 0.64 %
#
# 0.79 %
# 0.53 %
#
# 0.51 %
# 0.32 %
#
# 1.05 %
# 0.74 %
#
# 1.36 %
# 0.96 %
#
# 1.48 %
# 0.52 %
#
# 0.48 %
# 0.92 %
#
# 0.80 %
# 0.74 %
#
# 1.19 %
# 0.93 %
#
# 1.05 %
# 0.43 %
#
# 1.17 %
# 0.36 %
#
# 0.85 %
# 0.38 %
#
# 1.20 %
# 0.46 %
#
# 0.60 %
# 0.55 %
#
# 0.83 %
# 0.37 %
#
# 0.87 %
# 0.55 %
#
# 0.53 %
# 0.40 %
