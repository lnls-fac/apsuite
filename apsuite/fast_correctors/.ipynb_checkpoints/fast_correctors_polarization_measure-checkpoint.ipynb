# %%
import time
from epics import PV
import numpy as np
import matplotlib.pyplot as plt
import pymodels as pm
import pyaccel as pa
from apsuite.orbcorr.calc_orbcorr_mat import OrbRespmat

from siriuspy.search import PSSearch
from siriuspy.devices import SOFB

from mathphys.functions import save_pickle, load_pickle

# %%
# %load test.py
import time


def meas_corr_resp(data, corr_type, corr_idx, curr_delta=0.05):
    if corr_type == 'fch':
        corr_names = fch_names
        curr_sp = fch_curr_sp
        curr_rb = fch_curr_rb
    else:
        corr_names = fcv_names
        curr_sp = fcv_curr_sp
        curr_rb = fcv_curr_rb
    
    psname = corr_names[corr_idx]
    pv_sp = curr_sp[psname]
    pv_rb = curr_rb[psname]
    print(psname)
    
    datum = dict()
    datum['timestamp'] = time.time()
    datum['curr_delta'] = curr_delta
    datum['sofb_nr_points'] = sofb.nr_points
    
    value = pv_sp.value
    
    print('acquire orbit0: curr - delta/2 ... ', end='')
    pv_sp.value = value - curr_delta/2 
    time.sleep(0.2)
    datum['curr0'] = pv_rb.value
    sofb.cmd_reset()
    sofb.wait_buffer()  # wait for buffer to fill
    datum['orbx0'] = sofb.orbx
    datum['orby0'] = sofb.orby
    print(pv_sp.value, datum['curr0'])
    
    print('acquire orbit1: curr + delta/2 ... ', end='')
    pv_sp.value = value + curr_delta/2
    time.sleep(0.2)
    datum['curr1'] = pv_rb.value
    sofb.cmd_reset()
    sofb.wait_buffer()  # wait for buffer to fill
    datum['orbx1'] = sofb.orbx
    datum['orby1'] = sofb.orby
    print(pv_sp.value, datum['curr1'])
    
    print('restore corrector ... ', end='')
    pv_sp.value = value
    time.sleep(0.2)
    datum['curr_final'] = pv_rb.value
    print(pv_sp.value, datum['curr_final'])

    data[psname] = datum
    return psname

# %% [markdown]
# # Experiment

# %%
def meas_corr_resp(data, corr_type, corr_idx, curr_delta=0.05):
    if corr_type == 'fch':
        corr_names = fch_names
        curr_sp = fch_curr_sp
        curr_rb = fch_curr_rb
    else:
        corr_names = fcv_names
        curr_sp = fcv_curr_sp
        curr_rb = fcv_curr_rb
    
    psname = corr_names[corr_idx]
    pv_sp = curr_sp[psname]
    pv_rb = curr_rb[psname]
    print(psname)
    
    datum = dict()
    datum['timestamp'] = time.time()
    datum['curr_delta'] = curr_delta
    datum['sofb_nr_points'] = sofb.nr_points
    
    value = pv_sp.value
    
    print('acquire orbit0: curr - delta/2 ... ', end='')
    pv_sp.value = value - curr_delta/2 
    time.sleep(0.2)
    datum['curr0'] = pv_rb.value
    sofb.cmd_reset()
    sofb.wait_buffer()  # wait for buffer to fill
    datum['orbx0'] = sofb.orbx
    datum['orby0'] = sofb.orby
    print(pv_sp.value, datum['curr0'])
    
    print('acquire orbit1: curr + delta/2 ... ', end='')
    pv_sp.value = value + curr_delta/2
    time.sleep(0.2)
    datum['curr1'] = pv_rb.value
    sofb.cmd_reset()
    sofb.wait_buffer()  # wait for buffer to fill
    datum['orbx1'] = sofb.orbx
    datum['orby1'] = sofb.orby
    print(pv_sp.value, datum['curr1'])
    
    print('restore corrector ... ', end='')
    pv_sp.value = value
    time.sleep(0.2)
    datum['curr_final'] = pv_rb.value
    print(pv_sp.value, datum['curr_final'])

    data[psname] = datum
    return psname

# %%
def plot_corr_respm(data, corr_type, corr_idx, model_kick=10):
    if corr_type == 'fch':
        corr_names = fch_names
        curr_sp = fch_curr_sp
        cod_model = mat_orbx[:, corr_idx]
    else:
        corr_names = fcv_names
        curr_sp = fcv_curr_sp
        cod_model = mat_orby[:, corr_idx]
    psname = corr_names[corr_idx]
    
    datum = data[psname]
    cod_x = datum['orbx1'] - datum['orbx0']
    cod_y = datum['orby1'] - datum['orby0']
    cod = np.hstack((cod_x, cod_y))

    model_rescale = model_kick / 10.0
    
    plt.plot(1e6*cod_model*model_rescale, '-o', label=f'model ({model_kick} urad)')
    plt.plot(cod, '-o', label='measurement')
    plt.xlabel('BPM index')
    plt.ylabel('COD [um]')
    plt.title(psname)
    plt.legend()
    plt.show()

# %%
fch_names = PSSearch.get_psnames({'dev':'FCH'})
fcv_names = PSSearch.get_psnames({'dev':'FCV'})
data = load_pickle('fast-corrs-model-cod-signatures.pickle')
mat_orbx = data['mat_orbx']
mat_orby = data['mat_orby']

# %%
sofb = SOFB(SOFB.DEVICES.SI)

fch_curr_sp = {name: PV(name + ':Current-SP') for name in fch_names}
fcv_curr_sp = {name: PV(name + ':Current-SP') for name in fcv_names}
fch_curr_rb = {name: PV(name + ':Current-RB') for name in fch_names}
fcv_curr_rb = {name: PV(name + ':Current-RB') for name in fcv_names}

# %%
print('SOFB connected: ', sofb.connected)
for fch, fcv in zip(fch_names, fcv_names):
    pv_h, pv_v = fch_curr_sp[fch], fcv_curr_sp[fcv]
    pv_h_rb, pv_v_rb = fch_curr_rb[fch], fcv_curr_rb[fcv]
    print(fch, fcv, ' connected: ', pv_h.connected, pv_v.connected, pv_h_rb.connected, pv_v_rb.connected)
# Out:
# SOFB connected:  True
# SI-01M2:PS-FCH SI-01M2:PS-FCV  connected:  True True True True
# SI-01C2:PS-FCH SI-01C2:PS-FCV  connected:  True True True True
# SI-01C3:PS-FCH SI-01C3:PS-FCV  connected:  True True True True
# SI-02M1:PS-FCH SI-02M1:PS-FCV  connected:  True True True True
# SI-02M2:PS-FCH SI-02M2:PS-FCV  connected:  True True True True
# SI-02C2:PS-FCH SI-02C2:PS-FCV  connected:  True True True True
# SI-02C3:PS-FCH SI-02C3:PS-FCV  connected:  True True True True
# SI-03M1:PS-FCH SI-03M1:PS-FCV  connected:  True True True True
# SI-03M2:PS-FCH SI-03M2:PS-FCV  connected:  True True True True
# SI-03C2:PS-FCH SI-03C2:PS-FCV  connected:  True True True True
# SI-03C3:PS-FCH SI-03C3:PS-FCV  connected:  True True True True
# SI-04M1:PS-FCH SI-04M1:PS-FCV  connected:  True True True True
# SI-04M2:PS-FCH SI-04M2:PS-FCV  connected:  True True True True
# SI-04C2:PS-FCH SI-04C2:PS-FCV  connected:  True True True True
# SI-04C3:PS-FCH SI-04C3:PS-FCV  connected:  True True True True
# SI-05M1:PS-FCH SI-05M1:PS-FCV  connected:  True True True True
# SI-05M2:PS-FCH SI-05M2:PS-FCV  connected:  True True True True
# SI-05C2:PS-FCH SI-05C2:PS-FCV  connected:  True True True True
# SI-05C3:PS-FCH SI-05C3:PS-FCV  connected:  True True True True
# SI-06M1:PS-FCH SI-06M1:PS-FCV  connected:  True True True True
# SI-06M2:PS-FCH SI-06M2:PS-FCV  connected:  True True True True
# SI-06C2:PS-FCH SI-06C2:PS-FCV  connected:  True True True True
# SI-06C3:PS-FCH SI-06C3:PS-FCV  connected:  True True True True
# SI-07M1:PS-FCH SI-07M1:PS-FCV  connected:  True True True True
# SI-07M2:PS-FCH SI-07M2:PS-FCV  connected:  True True True True
# SI-07C2:PS-FCH SI-07C2:PS-FCV  connected:  True True True True
# SI-07C3:PS-FCH SI-07C3:PS-FCV  connected:  True True True True
# SI-08M1:PS-FCH SI-08M1:PS-FCV  connected:  True True True True
# SI-08M2:PS-FCH SI-08M2:PS-FCV  connected:  True True True True
# SI-08C2:PS-FCH SI-08C2:PS-FCV  connected:  True True True True
# SI-08C3:PS-FCH SI-08C3:PS-FCV  connected:  True True True True
# SI-09M1:PS-FCH SI-09M1:PS-FCV  connected:  True True True True
# SI-09M2:PS-FCH SI-09M2:PS-FCV  connected:  True True True True
# SI-09C2:PS-FCH SI-09C2:PS-FCV  connected:  True True True True
# SI-09C3:PS-FCH SI-09C3:PS-FCV  connected:  True True True True
# SI-10M1:PS-FCH SI-10M1:PS-FCV  connected:  True True True True
# SI-10M2:PS-FCH SI-10M2:PS-FCV  connected:  True True True True
# SI-10C2:PS-FCH SI-10C2:PS-FCV  connected:  True True True True
# SI-10C3:PS-FCH SI-10C3:PS-FCV  connected:  True True True True
# SI-11M1:PS-FCH SI-11M1:PS-FCV  connected:  True True True True
# SI-11M2:PS-FCH SI-11M2:PS-FCV  connected:  True True True True
# SI-11C2:PS-FCH SI-11C2:PS-FCV  connected:  True True True True
# SI-11C3:PS-FCH SI-11C3:PS-FCV  connected:  True True True True
# SI-12M1:PS-FCH SI-12M1:PS-FCV  connected:  True True True True
# SI-12M2:PS-FCH SI-12M2:PS-FCV  connected:  True True True True
# SI-12C2:PS-FCH SI-12C2:PS-FCV  connected:  True True True True
# SI-12C3:PS-FCH SI-12C3:PS-FCV  connected:  True True True True
# SI-13M1:PS-FCH SI-13M1:PS-FCV  connected:  True True True True
# SI-13M2:PS-FCH SI-13M2:PS-FCV  connected:  True True True True
# SI-13C2:PS-FCH SI-13C2:PS-FCV  connected:  True True True True
# SI-13C3:PS-FCH SI-13C3:PS-FCV  connected:  True True True True
# SI-14M1:PS-FCH SI-14M1:PS-FCV  connected:  True True True True
# SI-14M2:PS-FCH SI-14M2:PS-FCV  connected:  True True True True
# SI-14C2:PS-FCH SI-14C2:PS-FCV  connected:  True True True True
# SI-14C3:PS-FCH SI-14C3:PS-FCV  connected:  True True True True
# SI-15M1:PS-FCH SI-15M1:PS-FCV  connected:  True True True True
# SI-15M2:PS-FCH SI-15M2:PS-FCV  connected:  True True True True
# SI-15C2:PS-FCH SI-15C2:PS-FCV  connected:  True True True True
# SI-15C3:PS-FCH SI-15C3:PS-FCV  connected:  True True True True
# SI-16M1:PS-FCH SI-16M1:PS-FCV  connected:  True True True True
# SI-16M2:PS-FCH SI-16M2:PS-FCV  connected:  True True True True
# SI-16C2:PS-FCH SI-16C2:PS-FCV  connected:  True True True True
# SI-16C3:PS-FCH SI-16C3:PS-FCV  connected:  True True True True
# SI-17M1:PS-FCH SI-17M1:PS-FCV  connected:  True True True True
# SI-17M2:PS-FCH SI-17M2:PS-FCV  connected:  True True True True
# SI-17C2:PS-FCH SI-17C2:PS-FCV  connected:  True True True True
# SI-17C3:PS-FCH SI-17C3:PS-FCV  connected:  True True True True
# SI-18M1:PS-FCH SI-18M1:PS-FCV  connected:  True True True True
# SI-18M2:PS-FCH SI-18M2:PS-FCV  connected:  True True True True
# SI-18C2:PS-FCH SI-18C2:PS-FCV  connected:  True True True True
# SI-18C3:PS-FCH SI-18C3:PS-FCV  connected:  True True True True
# SI-19M1:PS-FCH SI-19M1:PS-FCV  connected:  True True True True
# SI-19M2:PS-FCH SI-19M2:PS-FCV  connected:  True True True True
# SI-19C2:PS-FCH SI-19C2:PS-FCV  connected:  True True True True
# SI-19C3:PS-FCH SI-19C3:PS-FCV  connected:  True True True True
# SI-20M1:PS-FCH SI-20M1:PS-FCV  connected:  True True True True
# SI-20M2:PS-FCH SI-20M2:PS-FCV  connected:  True True True True
# SI-20C2:PS-FCH SI-20C2:PS-FCV  connected:  True True True True
# SI-20C3:PS-FCH SI-20C3:PS-FCV  connected:  True True True True
# SI-01M1:PS-FCH SI-01M1:PS-FCV  connected:  True True True True

# %%
sofb.cmd_change_opmode_to_sloworb()
sofb.nr_points = 30

# %%
data=dict()
data['fch_names'] = fch_names
data['fcv_names'] = fcv_names

# %%
corr_idx, corr_type = 70, 'fcv'

curr_delta = 0.100  # [A]

meas_corr_resp(data, corr_type, corr_idx, curr_delta=curr_delta)

save_pickle(data, 'fast-corr-cod-signature-meas', True)

plot_corr_respm(data, corr_type, corr_idx, model_kick=4)
# Out:
# SI-18C2:PS-FCV
# acquire orbit0: curr - delta/2 ... -0.05 -0.05
# acquire orbit1: curr + delta/2 ... 0.05 0.05
# restore corrector ... 0.0 0.0

# %%
plot_corr_respm(data, corr_type, corr_idx, model_kick=4)

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Defining functions

# %%
def generate_model_orm():
    mod = pm.si.create_accelerator()
    fam = pm.si.get_family_data(mod)
    orbmat = OrbRespmat(mod, acc='SI', dim='4d')
    orbmat.ch_idx = np.array(fam['FCH']['index']).ravel()
    orbmat.cv_idx = np.array(fam['FCV']['index']).ravel()
    respmat_fofb = orbmat.get_respm()
    return respmat_fofb

def compute_orm(data, plot_flag=True):
    """"Return measured and model ORM."""
    mat_orb = generate_model_orm()
    meas_orm = np.zeros(mat_orb.shape)
    fch_names = data['fch_names']
    fcv_names = data['fcv_names']
    fc_names = fch_names + fcv_names 
    for j, fc_name in enumerate(fc_names):
        dat = data[fc_name]
        dcurr = dat['curr_delta']
        dorbx = (dat['orbx1'] - dat['orbx0'])
        dorby = (dat['orby1'] - dat['orby0'])
        dorb  = np.hstack([dorbx, dorby])
        meas_orm[:, j] = dorb
    alpha = compute_alpha(mat_orb, meas_orm)[None, :]
    norm_meas_orm = alpha*meas_orm
    
    # dorbj * alpha = ORM_j
    # alpha = 1/kick = 1/dcurr * curr2kick, so:
    # curr2kick = 1/(alpha*dcurr) 
    
    curr2kick = 1/(alpha*dcurr)
    return norm_meas_orm, mat_orb, curr2kick

def compare_orb_matrices(meas, mod, corr_type='h'):
    with plt.style.context(['science','notebook']):
        plt.figure(figsize=(12,9))
        if corr_type=='h':
            meas_orb = meas[:160, :80]
            mat_orb = mod[:160, :80]
        else:
            meas_orb = meas[160:, 80:]
            mat_orb = mod[160:, 80:]
        diff_matrix = (meas_orb - mat_orb)
#         print(diff_matrix)
        plt.pcolormesh(diff_matrix, cmap='seismic')
        plt.xlabel(f'FC{corr_type.upper()} idx')
        plt.ylabel('BPM idx')
        plt.xticks(np.arange(0, mat_orb.shape[1], 5))
        plt.title(f'Difference between measured and nominal ORM for FC{corr_type.upper()}', fontsize=16)
        plt.colorbar(label='($ORM_{meas}$ - $ORM_{model}$) [um]')
        plt.savefig(f'orm_fc{corr_type}_diff.png', dpi=300, transparent=False, facecolor='white')

def compute_alpha(matrix_meas, matrix_mod):
    n = matrix_mod.shape[1]
    alpha = np.zeros(n)
    for j in range(n):
        if j < 80:
            c_mod, c_meas = matrix_mod[:160, j], matrix_meas[:160, j]
        if j >= 80:
            c_mod, c_meas = matrix_mod[160:, j], matrix_meas[160:, j]
        alpha[j] = np.dot(c_mod, c_meas)/np.dot(c_mod, c_mod)
    return alpha

def compute_corrcoef(m1, m2):
    n = m1.shape[1]
    corrcoeff = np.zeros(n)
    for j in range(n):
        c1, c2 = m1[:, j], m2[:, j]
        c1 -= c1.mean()
        c2 -= c2.mean()
        corrcoeff[j] = (c1 @ c2)/np.sqrt(np.sum(c1**2) * np.sum(c2**2))
    return corrcoeff

# %% [markdown]
# ## Comparing ORM matrices

# %%
data = load_pickle('fast-corr-cod-signature-meas.pickle')

# %%
mat_orbx = mod_sig['mat_orbx'][:160, :]
mat_orby = mod_sig['mat_orby'][160:, :]

# %% [markdown]
# Comparing ORM diagonal blocks

# %%
meas_orm, mod_orm, curr2kick = compute_orm(data, 'h')   
compare_orb_matrices(meas_orm, mat_orb, 'h')
# Out:
# /home/jucelio/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: RuntimeWarning: invalid value encountered in double_scalars

# %%
compare_orb_matrices(meas_orm, mod_orm, 'v')

# %% [markdown]
# Taking a look in the conversion factor

# %%
x = np.arange(curr2kick.size)
plt.plot(x[:80], curr2kick.T[:80], c='tab:blue')
plt.plot(x[80:], curr2kick.T[80:], c='tab:orange')
plt.ylabel("Conversion factor [A/urad]")
plt.xlabel('Corrector Idx()')
plt.axvline(80, ls='--', c='k')
plt.annotate('FH correctors', xy=(15, -20))
plt.annotate('FV correctors', xy=(110, -20))
# Out:
# Text(110, -20, 'FV correctors')

# %% [markdown]
# Checking if the last FV corrector is with inverted polarization

# %%
fcv_names = data['fcv_names']
plt.plot(mod_orm[160:, -2], '-o', label='model (negative)', c='tab:blue')
plt.plot(meas_orm[160:, -2], '-o', label='measured', c='tab:green')
plt.title(fcv_names[-1])
plt.ylabel('$\Delta y$')
plt.xlabel('BPM idx')
plt.legend(loc='lower right', bbox_to_anchor = (1.4,0.5))
plt.savefig('fcv_corr_problem', dpi=300, transparent=False, facecolor='white')

# %% [markdown]
# Computing correlation coefficient

# %%
# First the correlation between the measures and model for FCH
fchx_mod = mod_orm[:160, :80]
fchx_meas = meas_orm[:160, :80]
ncols = fchx_meas.shape[1]
fchx_corrcoeff = compute_corrcoef(fchx_mod, fchx_meas)

# %%
# Correlation between the measures and model for FCV
fcvy_mod = mod_orm[160:, 80:]
fcvy_meas = meas_orm[160:, 80:]
ncols = fcvy_meas.shape[1]
fcvy_corrcoeff = compute_corrcoef(fcvy_mod, fcvy_meas)

# %% [markdown]
# Computing coupling between correctors

# %%
# Trying to find coupling in the measures for FCH
fchy_meas = meas_orm[160:, :80]
# If we kick with FCH, there is a signature relationated with the kick of FCV?
xy_corrcoeff = compute_corrcoef(fcvy_mod[:, :-1], fchy_meas)
alphaxy = compute_alpha(fchy_meas, fcvy_mod[:, :-1])

# %%
fig, ax = plt.subplots(1,2, figsize=(10,6))
ax[0].plot(xy_corrcoeff)
ax[0].set_title('XY: correlation coeff.')
ax[1].plot(alphaxy)
ax[1].set_title(r'XY: $\alpha$ scale factor [u rad]') 
ax[0].set_xlabel('FCH idx')
ax[1].set_xlabel('FCH idx')
ax[1].set_ylabel('Coupling estimative')
ax[0].set_ylabel('Person correlation')
# Out:
# Text(0, 0.5, 'Person correlation')

# %%
# Trying to find coupling in the measures for FCV
fcvx_meas = meas_orm[:160, 80:]
# If we kick with FCV, there is a signature relationated with the kick of FCH?
yx_corrcoeff = compute_corrcoef(fchx_mod[:, :-1], fcvx_meas)
alphayx = compute_alpha(fcvx_meas, fchx_mod[:, :-1])

# %%
fig, ax = plt.subplots(1,2, figsize=(10,6))
ax[0].plot(yx_corrcoeff)
ax[0].set_title('YX: correlation coeff.')
ax[0].set_xlabel('FCV idx')
ax[1].set_xlabel('FCV idx')
ax[1].set_ylabel('Coupling estimative')
ax[0].set_ylabel('Person correlation')

ax[1].plot(alphayx)
ax[1].set_title(r'YX: $\alpha$ scale factor [u rad]')
# Out:
# Text(0.5, 1.0, 'YX: $\\alpha$ scale factor [u rad]')

# %%
coupled_fch = np.where(xy_corrcoeff > 0.75)[0]
coupled_fcv = np.where(yx_corrcoeff > 0.75)[0]

# %%
double_coupled = []
for i in range(0, 80):
    if i in coupled_fch and i in coupled_fcv:
        double_coupled.append(i)

# %%
double_coupled
# Out:
# [3, 4, 17, 19, 22, 35, 36, 51, 52, 54, 65, 67, 68]

# %% [markdown]
# ## Taking a look in some of the coupled correctors:

# %%
idx = double_coupled[0]
fchy = meas_orm[160:, idx]
fcvy_model = mod_orm[160:, 80+idx]
plt.title(fch_names[idx])
plt.plot(fchy, label='FCH (Vertical kick)')
plt.plot(fcvy_model*0.1, label='0.1 * FCV (Vertical Kick)')
plt.xlabel('BPM idx')
plt.ylabel('')
plt.legend()

# %%
idx = double_coupled[5]
fchy = meas_orm[160:, idx]
fcvy_model = mod_orm[160:, 80+idx]
plt.title(fch_names[idx])
plt.plot(fchy, label='FCH (Vertical kick)')
plt.plot(fcvy_model*0.1, label='0.1 * FCV (Vertical Kick)')
plt.xlabel('BPM idx')
plt.ylabel('')
plt.legend()
